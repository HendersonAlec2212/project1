# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import os

# %%
# Import Data Into Pandas DataFrame

file = 'C:\Data\Project_1_Folder\SUV_Data_Total\SUV_Data_Total2.csv'
df_all = pd.read_csv(file)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\briti\\smu\\git repos\\Project 1\\project1\\output_data\\andrew'

# %%
df_all.dtypes
# Out:
# vf_BodyClass             object
# brandName                object
# vf_Make                  object
# modelName                object
# vf_Model                 object
# vf_ModelID              float64
# vf_ModelYear            float64
# mileage                   int64
# askPrice                  int64
# msrp                      int64
# vf_BasePrice            float64
# askPrice.1                int64
# color                    object
# interiorColor            object
# vf_BodyCabType           object
# vf_Doors                float64
# vf_EngineCylinders      float64
# vf_EngineHP             float64
# vf_FuelTypePrimary       object
# vf_FuelTypeSecondary     object
# vf_Series                object
# vf_Series2               object
# vf_SteeringLocation      object
# vf_TransmissionStyle     object
# vf_Trim                  object
# vf_Trim2                 object
# vf_Turbo                 object
# vin                      object
# dtype: object

# %%
df_all.describe()
# Out:
#           vf_ModelID   vf_ModelYear       mileage      askPrice          msrp  \
# count  553858.000000  553874.000000  5.538740e+05  5.538740e+05  5.538740e+05
# mean     3042.676217    2013.962735  6.284800e+04  2.528368e+05  2.670779e+05
# std      3376.437195       4.298945  5.313645e+04  2.235001e+07  2.286612e+07
# min      1703.000000    1984.000000  1.000000e+03  0.000000e+00  0.000000e+00
# 25%      1820.000000    2012.000000  2.361500e+04  9.972000e+03  1.050000e+04
# 50%      1865.000000    2015.000000  4.501200e+04  1.820600e+04  1.952600e+04
# 75%      2241.000000    2017.000000  9.173300e+04  2.795200e+04  2.976400e+04
# max     27165.000000    2020.000000  2.228027e+06  2.147484e+09  2.147484e+09
#
#         vf_BasePrice    askPrice.1       vf_Doors  vf_EngineCylinders  \
# count  151100.000000  5.538740e+05  545909.000000       541058.000000
# mean    39235.400973  2.528368e+05       4.093671            5.401292
# std     14566.551527  2.235001e+07       0.416944            1.298806
# min     17995.000000  0.000000e+00       2.000000            3.000000
# 25%     27895.000000  9.972000e+03       4.000000            4.000000
# 50%     36025.000000  1.820600e+04       4.000000            6.000000
# 75%     45560.000000  2.795200e+04       4.000000            6.000000
# max    395731.000000  2.147484e+09       5.000000           12.000000
#
#          vf_EngineHP
# count  308900.000000
# mean      255.355634
# std        64.141565
# min       111.304814
# 25%       200.000000
# 50%       250.000000
# 75%       290.000000
# max       815.341290

# %%
# elimiante cars w/o a proce since we will be leaning on price as a main component

df_clean = df_all.loc[(df_all['askPrice']>0) & (df_all['askPrice']<200000) & (df_all['mileage']<300000)]

mileage_per_year=(df_clean['mileage'] / (2020 - df_clean['vf_ModelYear']))

car_age = (2020-df_clean['vf_ModelYear'])

df_clean.insert(6, 'Vehicle Age', car_age)
df_clean.insert(8, 'Miles Driven Per Year', mileage_per_year)

df_clean = df_clean.drop(['modelName', 'vf_Make', 'vf_FuelTypeSecondary', 'vf_Series2', 'vf_SteeringLocation', 'vf_TransmissionStyle', 'vf_Trim2', 'vf_Turbo', 'vf_Doors', 'vf_BodyCabType', ], axis=1)

df_clean.head(25)
# Out:
#                                          vf_BodyClass  brandName  \
# 0   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 2   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 3   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 6   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 10  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 13  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 14  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...   CADILLAC
# 23  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET
# 29  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 32  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...   CADILLAC
# 36  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET
# 37  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 47  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...        GMC
# 54  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 56  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 61  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 63  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 66  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 68  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 69  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 72  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 73  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...        BMW
# 77  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD
# 80  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
# 82  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP
#
#           vf_Model  vf_ModelID  Vehicle Age  vf_ModelYear  \
# 0         Wrangler      1943.0          3.0        2017.0
# 2   Grand Cherokee      1949.0          5.0        2015.0
# 3      Wrangler JK     25197.0          2.0        2018.0
# 6           Escape      1798.0          4.0        2016.0
# 10        Cherokee      1945.0          3.0        2017.0
# 13   Expedition EL     25742.0          3.0        2017.0
# 14        Escalade      1843.0          4.0        2016.0
# 23        Traverse      1853.0          3.0        2017.0
# 29            Edge      1797.0          3.0        2017.0
# 32        Escalade      1843.0          7.0        2013.0
# 36           Tahoe      1852.0          3.0        2017.0
# 37        Wrangler      1943.0         11.0        2009.0
# 47           Yukon      1859.0          4.0        2016.0
# 54            Edge      1797.0          4.0        2016.0
# 56        Wrangler      1943.0          3.0        2017.0
# 61            Flex      1802.0          3.0        2017.0
# 63            Flex      1802.0          3.0        2017.0
# 66        Explorer      1800.0          5.0        2015.0
# 68        Wrangler      1943.0          4.0        2016.0
# 69        Explorer      1800.0          4.0        2016.0
# 72        Cherokee      1945.0          5.0        2015.0
# 73              X3      1719.0          3.0        2017.0
# 77   Expedition EL     25742.0          3.0        2017.0
# 80        Wrangler      1943.0          4.0        2016.0
# 82  Grand Cherokee      1949.0          4.0        2016.0
#
#     Miles Driven Per Year  mileage  askPrice   msrp  vf_BasePrice  askPrice.1  \
# 0             3214.000000     9642     39962  39962       37445.0       39962
# 2            10092.000000    50460     32962  32962           NaN       32962
# 3             2922.000000     5844     35962  35962           NaN       35962
# 6             8006.500000    32026     18962  18962           NaN       18962
# 10            2652.666667     7958     23462  23462       25645.0       23462
# 13           18367.000000    55101     25962  25962       49835.0       25962
# 14            7603.750000    30415     57962  57962           NaN       57962
# 23            8048.000000    24144     24462  24462       26750.0       24462
# 29            4617.000000    13851     34962  34962       40900.0       34962
# 32           13307.571429    93153     28962  28962           NaN       28962
# 36            2393.000000     7179     58962  58962       62030.0       58962
# 37            7512.181818    82634     17962  17962           NaN       17962
# 47            7233.250000    28933     53962  53962           NaN       53962
# 54            2812.500000    11250     24962  24962           NaN       24962
# 56             445.000000     1335     38840  38840       30445.0       38840
# 61            2833.333333     8500     30962  30962       32730.0       30962
# 63            3950.000000    11850     34962  34962       38230.0       34962
# 66            5539.200000    27696     26462  26462           NaN       26462
# 68            5288.000000    21152     38962  38962           NaN       38962
# 69           14052.500000    56210     29962  29962           NaN       29962
# 72            7596.000000    37980     16462  16462           NaN       16462
# 73            8093.000000    24279     33962  33962       42050.0       33962
# 77           10613.000000    31839     38962  38962       58695.0       38962
# 80            3694.250000    14777     27962  27962           NaN       27962
# 82            6239.250000    24957     35962  35962           NaN       35962
# 2                                    Overland
# 3                              JK (Open Body)
# 6                                         NaN
# 10  Latitude(USMex) Longitude(BUX) North(Can)
# 13                                        NaN
# 14                                        NaN
# 23                                        NaN
# 29                                        NaN
# 32                                        NaN
# 36                                        NaN
# 37                    Sahara/Unlimited Sahara
# 47                                        NaN
# 54                                        NaN
# 56                                     Sahara
# 61                                        NaN
# 63                                        NaN
# 66                                        NaN
# 68                                    Rubicon
# 69                                        NaN
# 72                                      Sport
# 73                               X3 xDrive28i
# 77                                        NaN
# 80                                      Sport
# 82                                   Overland
#
#                                                   vin
# 0   322d48b4c60b477e2f9ed6b702a04e79de7a7fa2896521...
# 2   2ef50172db46389b72f4e99178a8e7711de2adf0658249...
# 3   6cb1784ba994af798c878b3f0d5270e893d8605cf47f94...
# 6   8ee60b54b5fba668f4766d4209b6aabedf3ea10a703fe2...
# 10  1ed760e28dc35ab6945f53a563f9cbcf894ff39c3b8dde...
# 13  4abdc6bd81a6b37a0536345f4b5c1e3fea3c192a4f6710...
# 14  19c40fbe4c474c8caeff3e275604537940edb353895f3e...
# 23  184e61f62b3f4c4ada141d978837d027b3348742af8db8...
# 29  b5d34fe8483447e4f4dc30800ca776f3ef37e9bdc47464...
# 32  d8bd331e632ecabb2ae4d6bc992e4a2565a5b105bb2da1...
# 36  764c3cf34c7a4279a2c58eeed11eb8474a37b42aa6242b...
# 37  491ea825ec8ccefa0c92bacefaf4525d3ec4809d1ed1ab...
# 47  6b5ae6e17b5d42bb7c778282e3f07e10258a792e5bef61...
# 54  1dff44ef9ee5ea31b4ee0e0922097726410f5dabf18256...
# 56  8d494f6e5e69970888ebfad4c373aab92bb06cd934808d...
# 61  a8b82c5754c369ccdcc69157017fcb2b19662ed9c86b7e...
# 63  1f7146537c1928278f627fc4b6c2fff8eed21a8e776522...
# 66  5f5d0e5eaf57a74ede6b677c084a1fbcfe33bf66847422...
# 68  e650365ad42d9722f0a2d03cf0c0f59013517dfbca6c3f...
# 69  7668eed7c2b14822d3df2ca801f30f9a7ceddf173f2b31...
# 72  82762681d99de996963112a3d5e9a1455e9fc985884885...
# 73  320a0d70347260898ff7149be0c3468bdce812fa0a7ade...
# 77  4cb149812f33985f35af5d032573388c96be8b1a00471f...
# 80  c70f9177b0aa01d47d8e84cffbe7f943754065da053c9a...
# 82  217d481f9444a739560f4dbe083db5b5d56d6bd03e0dbd...

# %%
print('Number of Records: '+str(len(df_clean['vin'])))
# Out:
# Number of Records: 472832

# %%
df_clean = df_all.loc[df_all['askPrice']>0]
df_clean.head(51)
# Out:
#                                           vf_BodyClass  brandName    vf_Make  \
# 0    Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 2    Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 3    Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 6    Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 10   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 13   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 14   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...   CADILLAC   CADILLAC
# 23   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET  CHEVROLET
# 29   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 32   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...   CADILLAC   CADILLAC
# 36   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET  CHEVROLET
# 37   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 47   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...        GMC        GMC
# 54   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 56   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 61   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 63   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 66   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 68   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 69   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 72   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 73   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...        BMW        BMW
# 77   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 80   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 82   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 87   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 93   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...    LINCOLN    LINCOLN
# 94   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 96   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 111  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 119  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...      DODGE      DODGE
# 127  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 134  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET  CHEVROLET
# 138  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 147  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...      DODGE      DODGE
# 150  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 154  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 157  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 161  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...      BUICK      BUICK
# 164  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...    LINCOLN    LINCOLN
# 168  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 177  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 180  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 186  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 189  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 194  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 195  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 216  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 217  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 218  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET  CHEVROLET
# 219  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
#
#           modelName        vf_Model  vf_ModelID  vf_ModelYear  mileage  \
# 0          Wrangler        Wrangler      1943.0        2017.0     9642
# 2    Grand Cherokee  Grand Cherokee      1949.0        2015.0    50460
# 3       Wrangler JK     Wrangler JK     25197.0        2018.0     5844
# 6            Escape          Escape      1798.0        2016.0    32026
# 10         Cherokee        Cherokee      1945.0        2017.0     7958
# 13    Expedition EL   Expedition EL     25742.0        2017.0    55101
# 14         Escalade        Escalade      1843.0        2016.0    30415
# 23         Traverse        Traverse      1853.0        2017.0    24144
# 29             Edge            Edge      1797.0        2017.0    13851
# 32         Escalade        Escalade      1843.0        2013.0    93153
# 36            Tahoe           Tahoe      1852.0        2017.0     7179
# 37         Wrangler        Wrangler      1943.0        2009.0    82634
# 47            Yukon           Yukon      1859.0        2016.0    28933
# 54             Edge            Edge      1797.0        2016.0    11250
# 56         Wrangler        Wrangler      1943.0        2017.0     1335
# 61             Flex            Flex      1802.0        2017.0     8500
# 63             Flex            Flex      1802.0        2017.0    11850
# 66         Explorer        Explorer      1800.0        2015.0    27696
# 68         Wrangler        Wrangler      1943.0        2016.0    21152
# 69         Explorer        Explorer      1800.0        2016.0    56210
# 72         Cherokee        Cherokee      1945.0        2015.0    37980
# 73               X3              X3      1719.0        2017.0    24279
# 77    Expedition EL   Expedition EL     25742.0        2017.0    31839
# 80         Wrangler        Wrangler      1943.0        2016.0    14777
# 82   Grand Cherokee  Grand Cherokee      1949.0        2016.0    24957
# 87         Explorer        Explorer      1800.0        2016.0    39228
# 93              MKX             MKX      1813.0        2016.0    29708
# 94           Escape          Escape      1798.0        2017.0    17537
# 96         Cherokee        Cherokee      1945.0        2016.0    28943
# 111        Wrangler        Wrangler      1943.0        2017.0     7026
# 119         Durango         Durango      3508.0        2018.0    16723
# 127  Grand Cherokee  Grand Cherokee      1949.0        2015.0    27922
# 134           Tahoe           Tahoe      1852.0        2018.0     7490
# 138        Cherokee        Cherokee      1945.0        2014.0    30592
# 147         Durango         Durango      3508.0        2013.0   115264
# 150        Explorer        Explorer      1800.0        2013.0    56235
# 154        Wrangler        Wrangler      1943.0        2015.0    12754
# 157        Wrangler        Wrangler      1943.0        2017.0    10536
# 161         Enclave         Enclave      1841.0        2017.0    17893
# 164             MKX             MKX      1813.0        2013.0    60921
# 168            Flex            Flex      1802.0        2017.0    15002
# 177            Flex            Flex      1802.0        2017.0    10870
# 180  Grand Cherokee  Grand Cherokee      1949.0        2015.0    45628
# 186  Grand Cherokee  Grand Cherokee      1949.0        2016.0    17808
# 189        Explorer        Explorer      1800.0        2016.0    31681
# 194        Renegade        Renegade      6160.0        2017.0     5031
# 195        Explorer        Explorer      1800.0        2017.0    34732
# 216  Grand Cherokee  Grand Cherokee      1949.0        2017.0    26259
# 217   Expedition EL   Expedition EL     25742.0        2017.0    35241
# 218         Equinox         Equinox      1847.0        2017.0    12895
# 219      Expedition      Expedition      1799.0        2012.0    50765
#
#      askPrice   msrp  ...           vf_FuelTypePrimary  \
# 0       39962  39962  ...                     Gasoline
# 2       32962  32962  ...                     Gasoline
# 3       35962  35962  ...                     Gasoline
# 6       18962  18962  ...                     Gasoline
# 10      23462  23462  ...                     Gasoline
# 13      25962  25962  ...  Flexible Fuel Vehicle (FFV)
# 14      57962  57962  ...                     Gasoline
# 23      24462  24462  ...                     Gasoline
# 29      34962  34962  ...                     Gasoline
# 32      28962  28962  ...                     Gasoline
# 36      58962  58962  ...                     Gasoline
# 37      17962  17962  ...                     Gasoline
# 47      53962  53962  ...                     Gasoline
# 54      24962  24962  ...                     Gasoline
# 56      38840  38840  ...                     Gasoline
# 61      30962  30962  ...                     Gasoline
# 63      34962  34962  ...                     Gasoline
# 66      26462  26462  ...                     Gasoline
# 68      38962  38962  ...                     Gasoline
# 69      29962  29962  ...                     Gasoline
# 72      16462  16462  ...                     Gasoline
# 73      33962  33962  ...                     Gasoline
# 77      38962  38962  ...  Flexible Fuel Vehicle (FFV)
# 80      27962  27962  ...                     Gasoline
# 82      35962  35962  ...                     Gasoline
# 87      25962  25962  ...                     Gasoline
# 93      34962  34962  ...                     Gasoline
# 94      25962  25962  ...                     Gasoline
# 96      23462  23462  ...                     Gasoline
# 111     35462  35462  ...                     Gasoline
# 119     41962  41962  ...                     Gasoline
# 127     23962  23962  ...                     Gasoline
# 134     61962  61962  ...                     Gasoline
# 138     19962  19962  ...                     Gasoline
# 147     16962  16962  ...                     Gasoline
# 150     18462  18462  ...                     Gasoline
# 154     29962  29962  ...                     Gasoline
# 157     39962  39962  ...                     Gasoline
# 161     34962  34962  ...                     Gasoline
# 164     17962  17962  ...                     Gasoline
# 168     30962  30962  ...                     Gasoline
# 177     34962  34962  ...                     Gasoline
# 180     23962  23962  ...                     Gasoline
# 186     35962  35962  ...                     Gasoline
# 189     25462  25462  ...                     Gasoline
# 194     17962  17962  ...                     Gasoline
# 195     33962  33962  ...                     Gasoline
# 216     29962  29962  ...                     Gasoline
# 217     36962  36962  ...  Flexible Fuel Vehicle (FFV)
# 218     20962  20962  ...                     Gasoline
# 219     23962  23962  ...                     Gasoline
#
#             vf_FuelTypeSecondary               vf_Series vf_Series2  \
# 0                            NaN                      JK        NaN
# 2                            NaN                     NaN        NaN
# 3                            NaN        Unlimited Sahara        NaN
# 6                            NaN                Titanium        NaN
# 10                           NaN                      KL        NaN
# 13                      Gasoline          XLT/King Ranch        NaN
# 14                           NaN  ESV Premium Collection        NaN
# 23                           NaN                     1LT        NaN
# 29                           NaN                   Sport        NaN
# 32                           NaN   ESV Luxury Collection        NaN
# 36                 Ethanol (E85)                 Premier        NaN
# 37                           NaN                      JK        NaN
# 47                           NaN                  Denali        NaN
# 54                           NaN                     SEL        NaN
# 56                           NaN                      JK        NaN
# 61                           NaN                     SEL        NaN
# 63                           NaN                 Limited        NaN
# 66                           NaN                     XLT        NaN
# 68                           NaN                      JK        NaN
# 69                           NaN                   Sport        NaN
# 72                           NaN                     NaN        NaN
# 73                           NaN                     NaN        NaN
# 77                      Gasoline                 Limited        NaN
# 80                           NaN                      JK        NaN
# 82                           NaN                      WK        NaN
# 87                           NaN                     XLT        NaN
# 93                           NaN                 Reserve        NaN
# 94                           NaN                Titanium        NaN
# 96                           NaN                      KL        NaN
# 111                          NaN                      JK        NaN
# 119                          NaN                     R/T        NaN
# 127                          NaN                     NaN        NaN
# 134                Ethanol (E85)                 Premier        NaN
# 138                          NaN                     NaN        NaN
# 147                          NaN                     NaN        NaN
# 150                          NaN                     XLT        NaN
# 154                          NaN                     NaN        NaN
# 157                          NaN                      JK        NaN
# 161                          NaN           Leather Group        NaN
# 164                          NaN                     NaN        NaN
# 168                          NaN                 Limited        NaN
# 177                          NaN                 Limited        NaN
# 180                          NaN                     NaN        NaN
# 186                          NaN                      WK        NaN
# 189                          NaN                     XLT        NaN
# 194                          NaN                     NaN        NaN
# 195                          NaN                 Limited        NaN
# 216                          NaN                      WK        NaN
# 217                     Gasoline                 Limited        NaN
# 218                Ethanol (E85)                 LT / FL        NaN
# 219  Flexible Fuel Vehicle (FFV)              EL-Limited        NaN
#
#        vf_SteeringLocation  vf_TransmissionStyle  \
# 0    Left Hand Drive (LHD)                   NaN
# 2    Left Hand Drive (LHD)                   NaN
# 3    Left Hand Drive (LHD)                   NaN
# 6                      NaN                   NaN
# 10   Left Hand Drive (LHD)                   NaN
# 13   Left Hand Drive (LHD)                   NaN
# 14                     NaN                   NaN
# 23   Left Hand Drive (LHD)             Automatic
# 29   Left Hand Drive (LHD)                   NaN
# 32                     NaN                   NaN
# 36   Left Hand Drive (LHD)             Automatic
# 37   Left Hand Drive (LHD)                   NaN
# 47                     NaN                   NaN
# 54                     NaN                   NaN
# 56   Left Hand Drive (LHD)                   NaN
# 61   Left Hand Drive (LHD)                   NaN
# 63   Left Hand Drive (LHD)                   NaN
# 66                     NaN                   NaN
# 68   Left Hand Drive (LHD)                   NaN
# 69                     NaN                   NaN
# 72   Left Hand Drive (LHD)                   NaN
# 73   Left Hand Drive (LHD)             Automatic
# 77   Left Hand Drive (LHD)                   NaN
# 80   Left Hand Drive (LHD)                   NaN
# 82   Left Hand Drive (LHD)                   NaN
# 87                     NaN                   NaN
# 93                     NaN                   NaN
# 94   Left Hand Drive (LHD)                   NaN
# 96   Left Hand Drive (LHD)                   NaN
# 111  Left Hand Drive (LHD)                   NaN
# 119  Left Hand Drive (LHD)             Automatic
# 127  Left Hand Drive (LHD)                   NaN
# 134  Left Hand Drive (LHD)             Automatic
# 138  Left Hand Drive (LHD)                   NaN
# 147  Left Hand Drive (LHD)                   NaN
# 150                    NaN                   NaN
# 154  Left Hand Drive (LHD)                   NaN
# 157  Left Hand Drive (LHD)                   NaN
# 161  Left Hand Drive (LHD)             Automatic
# 164                    NaN                   NaN
# 168  Left Hand Drive (LHD)                   NaN
# 177  Left Hand Drive (LHD)                   NaN
# 180  Left Hand Drive (LHD)                   NaN
# 186  Left Hand Drive (LHD)                   NaN
# 189                    NaN                   NaN
# 194  Left Hand Drive (LHD)                   NaN
# 195  Left Hand Drive (LHD)                   NaN
# 216  Left Hand Drive (LHD)                   NaN
# 217  Left Hand Drive (LHD)                   NaN
# 218  Left Hand Drive (LHD)             Automatic
# 219                    NaN                   NaN
#
#                                        vf_Trim  vf_Trim2 vf_Turbo  \
# 0                            Unlimited Rubicon       NaN       No
# 2                                     Overland       NaN       No
# 3                               JK (Open Body)       NaN       No
# 6                                          NaN       NaN      NaN
# 10   Latitude(USMex) Longitude(BUX) North(Can)       NaN       No
# 13                                         NaN       NaN      NaN
# 14                                         NaN       NaN      NaN
# 23                                         NaN       NaN      NaN
# 29                                         NaN       NaN      NaN
# 32                                         NaN       NaN      NaN
# 36                                         NaN       NaN      NaN
# 37                     Sahara/Unlimited Sahara       NaN      NaN
# 47                                         NaN       NaN      NaN
# 54                                         NaN       NaN      NaN
# 56                                      Sahara       NaN       No
# 61                                         NaN       NaN      NaN
# 63                                         NaN       NaN      NaN
# 66                                         NaN       NaN      NaN
# 68                                     Rubicon       NaN       No
# 69                                         NaN       NaN      NaN
# 72                                       Sport       NaN       No
# 73                                X3 xDrive28i       NaN      NaN
# 77                                         NaN       NaN      NaN
# 80                                       Sport       NaN       No
# 82                                    Overland       NaN       No
# 87                                         NaN       NaN      NaN
# 93                                         NaN       NaN      NaN
# 94                                         NaN       NaN      NaN
# 96                                   Trailhawk       NaN       No
# 111                           Unlimited Sahara       NaN       No
# 119                                         WD       NaN       No
# 127                                     Laredo       NaN       No
# 134                                        NaN       NaN      NaN
# 138                                    Limited       NaN       No
# 147                                       Crew       NaN       No
# 150                                        NaN       NaN      NaN
# 154                                      Sport       NaN       No
# 157                          Unlimited Rubicon       NaN       No
# 161                                        NaN       NaN      NaN
# 164                                        NaN       NaN      NaN
# 168                                        NaN       NaN      NaN
# 177                                        NaN       NaN      NaN
# 180                                     Laredo       NaN       No
# 186                                   Overland       NaN       No
# 189                                        NaN       NaN      NaN
# 194                                      Sport       NaN       No
# 195                                        NaN       NaN      NaN
# 216                                    Limited       NaN       No
# 217                                        NaN       NaN      NaN
# 218                                        NaN       NaN      NaN
# 219                                        NaN       NaN      NaN
#
#                                                    vin
# 0    322d48b4c60b477e2f9ed6b702a04e79de7a7fa2896521...
# 2    2ef50172db46389b72f4e99178a8e7711de2adf0658249...
# 3    6cb1784ba994af798c878b3f0d5270e893d8605cf47f94...
# 6    8ee60b54b5fba668f4766d4209b6aabedf3ea10a703fe2...
# 10   1ed760e28dc35ab6945f53a563f9cbcf894ff39c3b8dde...
# 13   4abdc6bd81a6b37a0536345f4b5c1e3fea3c192a4f6710...
# 14   19c40fbe4c474c8caeff3e275604537940edb353895f3e...
# 23   184e61f62b3f4c4ada141d978837d027b3348742af8db8...
# 29   b5d34fe8483447e4f4dc30800ca776f3ef37e9bdc47464...
# 32   d8bd331e632ecabb2ae4d6bc992e4a2565a5b105bb2da1...
# 36   764c3cf34c7a4279a2c58eeed11eb8474a37b42aa6242b...
# 37   491ea825ec8ccefa0c92bacefaf4525d3ec4809d1ed1ab...
sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 2    Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 3    Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 6    Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 10   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 13   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 14   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...   CADILLAC   CADILLAC
# 23   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET  CHEVROLET
# 29   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 32   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...   CADILLAC   CADILLAC
# 36   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET  CHEVROLET
# 37   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 47   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...        GMC        GMC
# 54   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 56   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 61   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 63   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 66   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 68   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 69   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 72   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 73   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...        BMW        BMW
# 77   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 80   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 82   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 87   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 93   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...    LINCOLN    LINCOLN
# 94   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 96   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 111  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 119  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...      DODGE      DODGE
# 127  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 134  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET  CHEVROLET
# 138  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 147  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...      DODGE      DODGE
# 150  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 154  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 157  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 161  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...      BUICK      BUICK
# 164  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...    LINCOLN    LINCOLN
# 168  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 177  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 180  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 186  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 189  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 194  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 195  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 216  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       JEEP       JEEP
# 217  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       FORD       FORD
# 218  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...  CHEVROLET  CHEVROLET
#
#           modelName        vf_Model  vf_ModelID  vf_ModelYear  mileage  \
# 0          Wrangler        Wrangler      1943.0        2017.0     9642
# 2    Grand Cherokee  Grand Cherokee      1949.0        2015.0    50460
# 3       Wrangler JK     Wrangler JK     25197.0        2018.0     5844
# 6            Escape          Escape      1798.0        2016.0    32026
# 10         Cherokee        Cherokee      1945.0        2017.0     7958
# 13    Expedition EL   Expedition EL     25742.0        2017.0    55101
# 14         Escalade        Escalade      1843.0        2016.0    30415
# 23         Traverse        Traverse      1853.0        2017.0    24144
# 29             Edge            Edge      1797.0        2017.0    13851
# 32         Escalade        Escalade      1843.0        2013.0    93153
# 36            Tahoe           Tahoe      1852.0        2017.0     7179
# 37         Wrangler        Wrangler      1943.0        2009.0    82634
# 47            Yukon           Yukon      1859.0        2016.0    28933
# 54             Edge            Edge      1797.0        2016.0    11250
# 56         Wrangler        Wrangler      1943.0        2017.0     1335
# 61             Flex            Flex      1802.0        2017.0     8500
# 63             Flex            Flex      1802.0        2017.0    11850
# 66         Explorer        Explorer      1800.0        2015.0    27696
# 68         Wrangler        Wrangler      1943.0        2016.0    21152
# 69         Explorer        Explorer      1800.0        2016.0    56210
# 72         Cherokee        Cherokee      1945.0        2015.0    37980
# 73               X3              X3      1719.0        2017.0    24279
# 77    Expedition EL   Expedition EL     25742.0        2017.0    31839
# 80         Wrangler        Wrangler      1943.0        2016.0    14777
# 82   Grand Cherokee  Grand Cherokee      1949.0        2016.0    24957
# 87         Explorer        Explorer      1800.0        2016.0    39228
# 93              MKX             MKX      1813.0        2016.0    29708
# 94           Escape          Escape      1798.0        2017.0    17537
# 96         Cherokee        Cherokee      1945.0        2016.0    28943
# 111        Wrangler        Wrangler      1943.0        2017.0     7026
# 119         Durango         Durango      3508.0        2018.0    16723
# 127  Grand Cherokee  Grand Cherokee      1949.0        2015.0    27922
# 134           Tahoe           Tahoe      1852.0        2018.0     7490
# 138        Cherokee        Cherokee      1945.0        2014.0    30592
# 147         Durango         Durango      3508.0        2013.0   115264
# 150        Explorer        Explorer      1800.0        2013.0    56235
# 154        Wrangler        Wrangler      1943.0        2015.0    12754
# 157        Wrangler        Wrangler      1943.0        2017.0    10536
# 161         Enclave         Enclave      1841.0        2017.0    17893
# 164             MKX             MKX      1813.0        2013.0    60921
# 168            Flex            Flex      1802.0        2017.0    15002
# 177            Flex            Flex      1802.0        2017.0    10870
# 180  Grand Cherokee  Grand Cherokee      1949.0        2015.0    45628
# 186  Grand Cherokee  Grand Cherokee      1949.0        2016.0    17808
# 189        Explorer        Explorer      1800.0        2016.0    31681
# 194        Renegade        Renegade      6160.0        2017.0     5031
# 195        Explorer        Explorer      1800.0        2017.0    34732
# 216  Grand Cherokee  Grand Cherokee      1949.0        2017.0    26259
# 217   Expedition EL   Expedition EL     25742.0        2017.0    35241
# 218         Equinox         Equinox      1847.0        2017.0    12895
#
#      askPrice   msrp  ...           vf_FuelTypePrimary  vf_FuelTypeSecondary  \
# 0       39962  39962  ...                     Gasoline                   NaN
# 2       32962  32962  ...                     Gasoline                   NaN
# 3       35962  35962  ...                     Gasoline                   NaN
# 6       18962  18962  ...                     Gasoline                   NaN
# 10      23462  23462  ...                     Gasoline                   NaN
# 13      25962  25962  ...  Flexible Fuel Vehicle (FFV)              Gasoline
# 14      57962  57962  ...                     Gasoline                   NaN
# 23      24462  24462  ...                     Gasoline                   NaN
# 29      34962  34962  ...                     Gasoline                   NaN
# 32      28962  28962  ...                     Gasoline                   NaN
# 36      58962  58962  ...                     Gasoline         Ethanol (E85)
# 37      17962  17962  ...                     Gasoline                   NaN
# 47      53962  53962  ...                     Gasoline                   NaN
# 54      24962  24962  ...                     Gasoline                   NaN
# 56      38840  38840  ...                     Gasoline                   NaN
# 61      30962  30962  ...                     Gasoline                   NaN
# 63      34962  34962  ...                     Gasoline                   NaN
# 66      26462  26462  ...                     Gasoline                   NaN
# 68      38962  38962  ...                     Gasoline                   NaN
# 69      29962  29962  ...                     Gasoline                   NaN
# 72      16462  16462  ...                     Gasoline                   NaN
# 73      33962  33962  ...                     Gasoline                   NaN
# 77      38962  38962  ...  Flexible Fuel Vehicle (FFV)              Gasoline
# 80      27962  27962  ...                     Gasoline                   NaN
# 82      35962  35962  ...                     Gasoline                   NaN
# 87      25962  25962  ...                     Gasoline                   NaN
# 93      34962  34962  ...                     Gasoline                   NaN
# 94      25962  25962  ...                     Gasoline                   NaN
# 96      23462  23462  ...                     Gasoline                   NaN
# 111     35462  35462  ...                     Gasoline                   NaN
# 119     41962  41962  ...                     Gasoline                   NaN
# 127     23962  23962  ...                     Gasoline                   NaN
# 134     61962  61962  ...                     Gasoline         Ethanol (E85)
# 138     19962  19962  ...                     Gasoline                   NaN
# 147     16962  16962  ...                     Gasoline                   NaN
# 150     18462  18462  ...                     Gasoline                   NaN
# 154     29962  29962  ...                     Gasoline                   NaN
# 157     39962  39962  ...                     Gasoline                   NaN
# 161     34962  34962  ...                     Gasoline                   NaN
# 164     17962  17962  ...                     Gasoline                   NaN
# 168     30962  30962  ...                     Gasoline                   NaN
# 177     34962  34962  ...                     Gasoline                   NaN
# 180     23962  23962  ...                     Gasoline                   NaN
# 186     35962  35962  ...                     Gasoline                   NaN
# 189     25462  25462  ...                     Gasoline                   NaN
# 194     17962  17962  ...                     Gasoline                   NaN
# 195     33962  33962  ...                     Gasoline                   NaN
# 216     29962  29962  ...                     Gasoline                   NaN
# 217     36962  36962  ...  Flexible Fuel Vehicle (FFV)              Gasoline
# 218     20962  20962  ...                     Gasoline         Ethanol (E85)
#
#                   vf_Series vf_Series2    vf_SteeringLocation  \
# 0                        JK        NaN  Left Hand Drive (LHD)
# 2                       NaN        NaN  Left Hand Drive (LHD)
# 3          Unlimited Sahara        NaN  Left Hand Drive (LHD)
# 6                  Titanium        NaN                    NaN
# 10                       KL        NaN  Left Hand Drive (LHD)
# 13           XLT/King Ranch        NaN  Left Hand Drive (LHD)
# 14   ESV Premium Collection        NaN                    NaN
# 23                      1LT        NaN  Left Hand Drive (LHD)
# 29                    Sport        NaN  Left Hand Drive (LHD)
# 32    ESV Luxury Collection        NaN                    NaN
# 36                  Premier        NaN  Left Hand Drive (LHD)
# 37                       JK        NaN  Left Hand Drive (LHD)
# 47                   Denali        NaN                    NaN
# 54                      SEL        NaN                    NaN
# 56                       JK        NaN  Left Hand Drive (LHD)
# 61                      SEL        NaN  Left Hand Drive (LHD)
# 63                  Limited        NaN  Left Hand Drive (LHD)
# 66                      XLT        NaN                    NaN
# 68                       JK        NaN  Left Hand Drive (LHD)
# 69                    Sport        NaN                    NaN
# 72                      NaN        NaN  Left Hand Drive (LHD)
# 73                      NaN        NaN  Left Hand Drive (LHD)
# 77                  Limited        NaN  Left Hand Drive (LHD)
# 80                       JK        NaN  Left Hand Drive (LHD)
# 82                       WK        NaN  Left Hand Drive (LHD)
# 87                      XLT        NaN                    NaN
# 93                  Reserve        NaN                    NaN
# 94                 Titanium        NaN  Left Hand Drive (LHD)
# 96                       KL        NaN  Left Hand Drive (LHD)
# 111                      JK        NaN  Left Hand Drive (LHD)
# 119                     R/T        NaN  Left Hand Drive (LHD)
# 127                     NaN        NaN  Left Hand Drive (LHD)
# 134                 Premier        NaN  Left Hand Drive (LHD)
# 138                     NaN        NaN  Left Hand Drive (LHD)
# 147                     NaN        NaN  Left Hand Drive (LHD)
# 150                     XLT        NaN                    NaN
# 154                     NaN        NaN  Left Hand Drive (LHD)
# 157                      JK        NaN  Left Hand Drive (LHD)
# 161           Leather Group        NaN  Left Hand Drive (LHD)
# 164                     NaN        NaN                    NaN
# 168                 Limited        NaN  Left Hand Drive (LHD)
# 177                 Limited        NaN  Left Hand Drive (LHD)
# 180                     NaN        NaN  Left Hand Drive (LHD)
# 186                      WK        NaN  Left Hand Drive (LHD)
# 189                     XLT        NaN                    NaN
# 194                     NaN        NaN  Left Hand Drive (LHD)
# 195                 Limited        NaN  Left Hand Drive (LHD)
# 216                      WK        NaN  Left Hand Drive (LHD)
# 217                 Limited        NaN  Left Hand Drive (LHD)
# 218                 LT / FL        NaN  Left Hand Drive (LHD)
#
#      vf_TransmissionStyle                                    vf_Trim  \
# 0                     NaN                          Unlimited Rubicon
# 2                     NaN                                   Overland
# 3                     NaN                             JK (Open Body)
# 6                     NaN                                        NaN
# 10                    NaN  Latitude(USMex) Longitude(BUX) North(Can)
# 13                    NaN                                        NaN
# 69        NaN      NaN  7668eed7c2b14822d3df2ca801f30f9a7ceddf173f2b31...
# 72        NaN       No  82762681d99de996963112a3d5e9a1455e9fc985884885...
# 73        NaN      NaN  320a0d70347260898ff7149be0c3468bdce812fa0a7ade...
# 77        NaN      NaN  4cb149812f33985f35af5d032573388c96be8b1a00471f...
# 80        NaN       No  c70f9177b0aa01d47d8e84cffbe7f943754065da053c9a...
# 82        NaN       No  217d481f9444a739560f4dbe083db5b5d56d6bd03e0dbd...
# 87        NaN      NaN  1a89774ec9386be1bc07e6bb6dde782096b7f3cf46c555...
# 93        NaN      NaN  d2eb71aa1d45e27f8c71c0f803d6b97d9f2a145802e68d...
# 94        NaN      NaN  ca9cdaf654f1ebe339ed1e69f70b2662eb585792cab659...
# 96        NaN       No  587e95f1004468f3f942bb2425fcd0d687560f7bb5af9f...
# 111       NaN       No  35540fb0808b12ec4fa1c1087114d52ca392f43c7dc011...
# 119       NaN       No  9cffc5918a6b9f807525642e9316188f56f8e3e811e899...
# 127       NaN       No  abe670ea0f7c398c7afc10c0b63fda59a3d6010d188bc9...
# 134       NaN      NaN  da4361fe184bcb771b7c2fa4f5b109a579cf44bd069803...
# 138       NaN       No  4985206c21ee40b009ac217ba52d6603de18cf299d21fd...
# 147       NaN       No  95c26b65aa72f7c2182495c95659c29a67ed5ebce1ec94...
# 150       NaN      NaN  6dee401cd0b3d0793079c14a6c79b38bcb2d76b4ccea49...
# 154       NaN       No  6cefa95e82adb4383a05f1da51233d8ad17f66cacb8424...
# 157       NaN       No  cb134825f40ad94a2c67f6b4ccc2f9c72d3ed5861f39a7...
# 161       NaN      NaN  8709b7d47cfcb0f4b57657e9976cea2f1f4963453df6bb...
# 164       NaN      NaN  c6823b7e5e991fcc1ac12df0cb9841421b7a2873bd3027...
# 168       NaN      NaN  3ad0ccd6e64ed584052f1425eb76c585776eb60cd653c8...
# 177       NaN      NaN  1b0970b2c9dddf970021f1c980412a96fc9ae99179ee95...
# 180       NaN       No  744d9f581368d22477c98bd7ef8bf9017dd0b93a32a741...
# 186       NaN       No  307a7536e59af9b7a427fc711dae57ab0b78e5d4519e22...
# 189       NaN      NaN  6c7c19a9ab8b1f1a2a46adc86aa6b37124da1a5e74ae1a...
# 194       NaN       No  be33a8171c64ee0174e64a283bb9268ed16185ff5b14c1...
# 195       NaN      NaN  b559d92e81e9716dee486b9ed75953f03539bc0c586f27...
# 216       NaN       No  26be7e83ade8fe50170d444ac6601a4e7a03ac3389d706...
# 217       NaN      NaN  ab16a403c9c82271cc833b27929d10e1e021164e1b964d...
# 218       NaN      NaN  b0c109e6934054f6669f3770ad0a5d32fa29769b4855ee...
#
# [50 rows x 28 columns]

# %%
df_clean1['color'].isnull().sum()
# Out:
# 11624

# %%
col_list = df_clean1.columns.tolist()
num_col = len(col_list)
num_nan_list = []
num_unq_list = []
per_nan_list = []

for x in range(num_col):
    num_nan_list.append(df_clean1[col_list[x]].isnull().sum())

for x in range(num_col):
    num_unq_list.append(df_clean1[col_list[x]].nunique())
    
for x in range(num_col):
    per_nan_list.append('{:,.2f}%'.format(((num_nan_list[x])/(len(df_clean1['vin'])))*100))

analysis_dict = {'Column Name':col_list,
                 'Number Missing':num_nan_list,
                 'Percentage Missing': per_nan_list,
                 'Number Unique Items': num_unq_list
                 }
analysis_df = pd.DataFrame(analysis_dict)
analysis_df.set_index(['Column Name'], inplace=True)
analysis_df.head(31)
# Out:
#                       Number Missing Percentage Missing  Number Unique Items
# Column Name
# vf_BodyClass                       0              0.00%                    1
# brandName                          0              0.00%                   44
# vf_Make                            0              0.00%                   44
# modelName                         13              0.00%                  178
# vf_Model                          13              0.00%                  178
# vf_ModelID                        13              0.00%                  179
# vf_ModelYear                       0              0.00%                   33
# mileage                            0              0.00%                90923
# askPrice                           0              0.00%                32568
# msrp                               0              0.00%                32629
# vf_BasePrice                  331953             70.17%                  681
# askPrice.1                         0              0.00%                32568
# color                          11624              2.46%                 3802
# interiorColor                  76222             16.11%                 3670
# vf_BodyCabType                470717             99.51%                    2
# vf_Doors                        6306              1.33%                    4
# vf_EngineCylinders             10785              2.28%                    7
# vf_EngineHP                   201101             42.51%                  157
# vf_FuelTypePrimary              8395              1.77%                    4
# vf_FuelTypeSecondary          424339             89.70%                    5
# vf_Series                     112659             23.82%                  685
# vf_Series2                    452185             95.59%                   22
# vf_SteeringLocation           260235             55.01%                    2
# vf_TransmissionStyle          330877             69.95%                    5
# vf_Trim                       261088             55.19%                  539
# vf_Trim2                      468195             98.97%                    5
# vf_Turbo                      343512             72.62%                    2
# vin                                0              0.00%               160588

# %%
# Analyze Unique Values in BodyCabType
# Remove As Identifiers are Not Descrptive Enough

df_clean1.groupby('vf_BodyCabType')['vin'].count()
# Out:
# vf_BodyCabType
# Extra/Super/ Quad/Double/King/Extended       2
# Not Applicable                            2328
# Name: vin, dtype: int64

# %%
df_clean2 = df_clean1[['brandName',
                       'modelName',
                       'vf_ModelID',
                       'vf_ModelYear',
                       'mileage',
                       'askPrice',
                       'msrp',
                       'color',
                       'vf_EngineCylinders',
                       'vf_FuelTypePrimary',
                       'vin'
                      ]]
df_clean2.head(50)
# Out:
#      brandName       modelName  vf_ModelID  vf_ModelYear  mileage  askPrice  \
# 0         JEEP        Wrangler      1943.0        2017.0     9642     39962
# 2         JEEP  Grand Cherokee      1949.0        2015.0    50460     32962
# 3         JEEP     Wrangler JK     25197.0        2018.0     5844     35962
# 6         FORD          Escape      1798.0        2016.0    32026     18962
# 10        JEEP        Cherokee      1945.0        2017.0     7958     23462
# 13        FORD   Expedition EL     25742.0        2017.0    55101     25962
# 14    CADILLAC        Escalade      1843.0        2016.0    30415     57962
# 23   CHEVROLET        Traverse      1853.0        2017.0    24144     24462
# 29        FORD            Edge      1797.0        2017.0    13851     34962
# 32    CADILLAC        Escalade      1843.0        2013.0    93153     28962
# 36   CHEVROLET           Tahoe      1852.0        2017.0     7179     58962
# 37        JEEP        Wrangler      1943.0        2009.0    82634     17962
# 47         GMC           Yukon      1859.0        2016.0    28933     53962
# 54        FORD            Edge      1797.0        2016.0    11250     24962
# 56        JEEP        Wrangler      1943.0        2017.0     1335     38840
# 194  be33a8171c64ee0174e64a283bb9268ed16185ff5b14c1...
# 195  b559d92e81e9716dee486b9ed75953f03539bc0c586f27...
# 216  26be7e83ade8fe50170d444ac6601a4e7a03ac3389d706...
# 217  ab16a403c9c82271cc833b27929d10e1e021164e1b964d...
# 218  b0c109e6934054f6669f3770ad0a5d32fa29769b4855ee...

# %%
df_clean2.dropna(axis=0, how='any', inplace=True)
# Out:
# <ipython-input-17-4c73de67bed6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean2.dropna(axis=0, how='any', inplace=True)

# %%
print('Number of Records: '+str(len(df_clean2['vin'])))
# Out:
# Number of Records: 446013

# %%
col_list = df_clean2.columns.tolist()
num_col = len(col_list)
num_nan_list = []
num_unq_list = []
per_nan_list = []

for x in range(num_col):
    num_nan_list.append(df_clean2[col_list[x]].isnull().sum())

for x in range(num_col):
    num_unq_list.append(df_clean2[col_list[x]].nunique())
    
for x in range(num_col):
    per_nan_list.append('{:,.2f}%'.format(((num_nan_list[x])/(len(df_clean2['vin'])))*100))

analysis_dict = {'Column Name':col_list,
                 'Number Missing':num_nan_list,
                 'Percentage Missing': per_nan_list,
                 'Number Unique Items': num_unq_list
                 }
analysis_df = pd.DataFrame(analysis_dict)
analysis_df.set_index(['Column Name'], inplace=True)
analysis_df.head(31)
# Out:
#                     Number Missing Percentage Missing  Number Unique Items
# Column Name
# brandName                        0              0.00%                   40
# modelName                        0              0.00%                  161
# vf_ModelID                       0              0.00%                  162
# vf_ModelYear                     0              0.00%                   33
# mileage                          0              0.00%                87280
# askPrice                         0              0.00%                31639
# msrp                             0              0.00%                31593
# color                            0              0.00%                 3591
# vf_EngineCylinders               0              0.00%                    7
# vf_FuelTypePrimary               0              0.00%                    4
# vin                              0              0.00%               152655

# %%
df_clean3 = df_clean2.drop_duplicates(subset='vin',keep='first')
print('Number of Records: '+str(len(df_clean3['vin'])))
# Out:
# Number of Records: 152655

# %%
df_clean3.to_csv('C:\Data\SUV_Clean_Total.csv',index=False,header=True)
print('File_Saved')
# Out:
# File_Saved

# %%
df_clean3.describe()
# Out:
#           vf_ModelID   vf_ModelYear        mileage      askPrice  \
# count  152655.000000  152655.000000  152655.000000  1.526550e+05
# mean     3084.985503    2014.922498   51418.870781  7.282081e+05
# std      3559.292051       3.412852   42605.669295  3.885890e+07
# min      1703.000000    1985.000000    1000.000000  1.000000e+00
# 25%      1814.000000    2014.000000   20838.500000  1.499900e+04
# 50%      1865.000000    2016.000000   38125.000000  2.149000e+04
# 75%      2147.000000    2017.000000   73013.500000  3.029150e+04
# max     27165.000000    2020.000000  949278.000000  2.147484e+09
#
#                msrp  vf_EngineCylinders
# count  1.526550e+05       152655.000000
# mean   7.388848e+05            5.307255
# std    3.901457e+07            1.277254
# min    1.000000e+00            3.000000
# 25%    1.599500e+04            4.000000
# 50%    2.297700e+04            6.000000
# 75%    3.200000e+04            6.000000
# max    2.147484e+09           12.000000

# %%
df_clean3.head(30)
# Out:
#      brandName       modelName  vf_ModelID  vf_ModelYear  mileage  askPrice  \
# 0         JEEP        Wrangler      1943.0        2017.0     9642     39962
# 2         JEEP  Grand Cherokee      1949.0        2015.0    50460     32962
# 3         JEEP     Wrangler JK     25197.0        2018.0     5844     35962
# 6         FORD          Escape      1798.0        2016.0    32026     18962
# 10        JEEP        Cherokee      1945.0        2017.0     7958     23462
# 13        FORD   Expedition EL     25742.0        2017.0    55101     25962
# 14    CADILLAC        Escalade      1843.0        2016.0    30415     57962
# 23   CHEVROLET        Traverse      1853.0        2017.0    24144     24462
# 29        FORD            Edge      1797.0        2017.0    13851     34962
# 32    CADILLAC        Escalade      1843.0        2013.0    93153     28962
# 36   CHEVROLET           Tahoe      1852.0        2017.0     7179     58962
# 37        JEEP        Wrangler      1943.0        2009.0    82634     17962
# 47         GMC           Yukon      1859.0        2016.0    28933     53962
# 54        FORD            Edge      1797.0        2016.0    11250     24962
# 56        JEEP        Wrangler      1943.0        2017.0     1335     38840
# 61        FORD            Flex      1802.0        2017.0     8500     30962
# 63        FORD            Flex      1802.0        2017.0    11850     34962
# 66        FORD        Explorer      1800.0        2015.0    27696     26462
# 68        JEEP        Wrangler      1943.0        2016.0    21152     38962
# 69        FORD        Explorer      1800.0        2016.0    56210     29962
# 72        JEEP        Cherokee      1945.0        2015.0    37980     16462
# 73         BMW              X3      1719.0        2017.0    24279     33962
# 77        FORD   Expedition EL     25742.0        2017.0    31839     38962
# 80        JEEP        Wrangler      1943.0        2016.0    14777     27962
# 82        JEEP  Grand Cherokee      1949.0        2016.0    24957     35962
# 87        FORD        Explorer      1800.0        2016.0    39228     25962
# 93     LINCOLN             MKX      1813.0        2016.0    29708     34962
# 94        FORD          Escape      1798.0        2017.0    17537     25962
# 96        JEEP        Cherokee      1945.0        2016.0    28943     23462
# 111       JEEP        Wrangler      1943.0        2017.0     7026     35462
#
#       msrp                                         color  vf_EngineCylinders  \
# 0    39962                               Black Clearcoat                 6.0
# 2    32962                            Cashmere Pearlcoat                 8.0
# 3    35962                     Firecracker Red Clearcoat                 6.0
# 6    18962            Ruby Red Metallic Tinted Clearcoat                 4.0
# 10   23462               Diamond Black Crystal Pearlcoat                 6.0
# 13   25962                                  Oxford White                 6.0
# 14   57962                                   Black Raven                 8.0
# 23   24462                                  Summit White                 6.0
# 29   34962              White Platinum Metallic Tri-Coat                 6.0
# 32   28962                                   Black Raven                 8.0
# 36   58962                      Iridescent Pearl Tricoat                 8.0
# 37   17962  Jeep Green Metallic Clearcoat/Black Hard Top                 6.0
# 47   53962                                    Onyx Black                 8.0
# 54   24962                                  Shadow Black                 4.0
# 56   38840            Granite Crystal Metallic Clearcoat                 6.0
# 61   30962              White Platinum Metallic Tri-Coat                 6.0
# 63   34962              White Platinum Metallic Tri-Coat                 6.0
# 66   26462                         Tuxedo Black Metallic                 6.0
# 68   38962                        Bright White Clearcoat                 6.0
# 69   29962                                  Shadow Black                 6.0
# 72   16462              Billet Silver Metallic Clearcoat                 4.0
# 73   33962                       Black Sapphire Metallic                 4.0
# 77   38962                                    White Gold                 6.0
# 80   27962                     Firecracker Red Clearcoat                 6.0
# 82   35962              Billet Silver Metallic Clearcoat                 6.0
# 87   25962                           Blue Jeans Metallic                 6.0
# 111  35540fb0808b12ec4fa1c1087114d52ca392f43c7dc011...

# %%
# Linear Regression Using SKLearn

#1. Determine X & y

x = df_clean3['askPrice'].values
y = df_clean3['mileage'].values

#2. Split the Dataset in Training Set and Test Set

x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=0)

# Visualize Data Split

plt.scatter(x_train,y_train, label='Training Data', color='r',alpha=.7)
plt.scatter(x_test,y_test, label='Testing Data', color='g',alpha=.7)
plt.legend()

# %%
#3. Train the Model on the Training Set

LR =LinearRegression().fit(x_train.reshape(-1,1),y_train)

# Use Model to Predict on Test Data

prediction = LR.predict(x_test.reshape(-1,1))

# Plot Prediction Line Against Actual Test Data

plt.plot(x_test, prediction, label = 'Linear Regression',color='r')
plt.scatter(x_test,y_test,label = 'Actual Test Data',color='b',alpha=.7,edgecolors='k')
plt.legend()
plt.title('Mileage vs. MSRP (10/28/2021)')
plt.xlabel('Ask Price')
plt.ylabel('Mileage')
plt.grid(True)
plt.show()

# Evaluate the Model
scr = LR.score(x_train.reshape(-1,1),y_train)
scr = '{:,.2f}%'.format(scr*100)
print('The Overall Accuracry of the Model is: '+scr)

r2 = r2_score(y_test,prediction)
print('The R^2 Value of the Linear Regression Model is: '+str(r2))


m = float(LR.coef_)
m=  '{:,.2f}'.format(m)
b= float(LR.intercept_)
b=  '{:,.2f}'.format(b)

print('The Linear Equation of the Regression is: Y='+str(m)+'X + '+str(b))
# Out:
# The Overall Accuracry of the Model is: 0.00%
# The R^2 Value of the Linear Regression Model is: -3.475331800473214e-05
# The Linear Equation of the Regression is: Y=0.00X + 51,352.64

# %%
# Linear Regression Using SKLearn

#1. Determine X & y

x = df_clean3['vf_ModelYear'].values
y = df_clean3['mileage'].values

#2. Split the Dataset in Training Set and Test Set

x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=0)

# Visualize Data Split

plt.scatter(x_train,y_train, label='Training Data', color='r',alpha=.7)
plt.scatter(x_test,y_test, label='Testing Data', color='g',alpha=.7)
plt.legend()

# %%
#3. Train the Model on the Training Set

LR =LinearRegression().fit(x_train.reshape(-1,1),y_train)

# Use Model to Predict on Test Data

prediction = LR.predict(x_test.reshape(-1,1))

# Plot Prediction Line Against Actual Test Data

plt.plot(x_test, prediction, label = 'Linear Regression',color='r')
plt.scatter(x_test,y_test,label = 'Actual Test Data',color='b',alpha=.7,edgecolors='k')
plt.legend()
plt.title('Mileage vs. MSRP (10/28/2021)')
plt.xlabel('vf_ModelYear')
plt.ylabel('Mileage')
plt.grid(True)
plt.show()

# Evaluate the Model
scr = LR.score(x_train.reshape(-1,1),y_train)
scr = '{:,.2f}%'.format(scr*100)
print('The Overall Accuracry of the Model is: '+scr)

r2 = r2_score(y_test,prediction)
print('The R^2 Value of the Linear Regression Model is: '+str(r2))


m = float(LR.coef_)
m=  '{:,.2f}'.format(m)
b= float(LR.intercept_)
b=  '{:,.2f}'.format(b)

print('The Linear Equation of the Regression is: Y='+str(m)+'X + '+str(b))
# Out:
# The Overall Accuracry of the Model is: 65.60%
# The R^2 Value of the Linear Regression Model is: 0.6625981269804007
# The Linear Equation of the Regression is: Y=-10,107.73X + 20,417,653.02

# %%
# Linear Regression Using SKLearn

#1. Determine X & y

x = df_clean3['askPrice'].values
y = df_clean3['vf_ModelYear'].values

#2. Split the Dataset in Training Set and Test Set

x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=0)

# Visualize Data Split

plt.scatter(x_train,y_train, label='Training Data', color='r',alpha=.7)
plt.scatter(x_test,y_test, label='Testing Data', color='g',alpha=.7)
plt.legend()

# %%
#3. Train the Model on the Training Set

LR =LinearRegression().fit(x_train.reshape(-1,1),y_train)

# Use Model to Predict on Test Data

prediction = LR.predict(x_test.reshape(-1,1))

# Plot Prediction Line Against Actual Test Data

plt.plot(x_test, prediction, label = 'Linear Regression',color='r')
plt.scatter(x_test,y_test,label = 'Actual Test Data',color='b',alpha=.7,edgecolors='k')
plt.legend()
plt.title('Mileage vs. MSRP (10/28/2021)')
plt.xlabel('askPrice')
plt.ylabel('vf_ModelYear')
plt.grid(True)
plt.show()

# Evaluate the Model
scr = LR.score(x_train.reshape(-1,1),y_train)
scr = '{:,.2f}%'.format(scr*100)
print('The Overall Accuracry of the Model is: '+scr)

r2 = r2_score(y_test,prediction)
print('The R^2 Value of the Linear Regression Model is: '+str(r2))


m = float(LR.coef_)
m=  '{:,.2f}'.format(m)
b= float(LR.intercept_)
b=  '{:,.2f}'.format(b)

print('The Linear Equation of the Regression is: Y='+str(m)+'X + '+str(b))
# Out:
# The Overall Accuracry of the Model is: 0.00%
# The R^2 Value of the Linear Regression Model is: -6.548081850077381e-07
# The Linear Equation of the Regression is: Y=0.00X + 2,014.92

# %%
# Linear Regression Using SKLearn

#1. Determine X & y

x = df_clean3['askPrice'].values
y = df_clean3['brandName'].values

#2. Split the Dataset in Training Set and Test Set

x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=0)

# Visualize Data Split

plt.scatter(x_train,y_train, label='Training Data', color='r',alpha=.7)
plt.scatter(x_test,y_test, label='Testing Data', color='g',alpha=.7)
plt.legend()

# %%
# The maximum x value for our chart will be 100
x_limit = 6000

# List of values from 0 to 100 each value being 1 greater than the last
x_axis = np.arange(0, x_limit, 1)

# Create a random array of data that we will use for our y values
data = [random.random() for value in x_axis]

# %%
# Tells matplotlib that we want to make a scatter plot
# The size of each point on our plot is determined by their x value
plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black",
            s=x_axis, alpha=0.75)

# %%
# Set x axis and tick locations
x_axis = np.arange(len(df_clean3))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
make_list = df_clean3['brandName'].value_counts().index.to_list()
make_amount = df_clean3['brandName'].value_counts().to_list()
plt.bar(make_list[1:20], make_amount[1:20])
plt.xticks(rotation=90)
plt.show ()

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
make_list = df_clean3['vf_ModelYear'].value_counts().index.to_list()
make_amount = df_clean3['vf_ModelYear'].value_counts().to_list()
plt.bar(make_list[1:20], make_amount[1:20])
plt.xticks(rotation=90)
plt.show ()
